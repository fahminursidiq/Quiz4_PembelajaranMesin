# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9630b03d-b20b-463c-8941-0bc9e7263e6d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9630b03d-b20b-463c-8941-0bc9e7263e6d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Emissions_Canada.csv to Emissions_Canada.csv

# %%
import pandas as pd
df = pd.read_csv('Emissions_Canada.csv')
print(df)
# Out:
#        Make        Model   Vehicle Class  Engine Size(L)  Cylinders  \
# 0     ACURA          ILX         COMPACT             2.0          4
# 1     ACURA          ILX         COMPACT             2.4          4
# 2     ACURA   ILX HYBRID         COMPACT             1.5          4
# 3     ACURA      MDX 4WD     SUV - SMALL             3.5          6
# 4     ACURA      RDX AWD     SUV - SMALL             3.5          6
# ...     ...          ...             ...             ...        ...
# 7380  VOLVO  XC40 T5 AWD     SUV - SMALL             2.0          4
# 7381  VOLVO  XC60 T5 AWD     SUV - SMALL             2.0          4
# 7382  VOLVO  XC60 T6 AWD     SUV - SMALL             2.0          4
# 7383  VOLVO  XC90 T5 AWD  SUV - STANDARD             2.0          4
# 7384  VOLVO  XC90 T6 AWD  SUV - STANDARD             2.0          4
#
#      Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 0             AS5         Z                               9.9
# ...

# %%
df.describe()
# Out:
#        Engine Size(L)    Cylinders  Fuel Consumption City (L/100 km)  \
# count     7385.000000  7385.000000                       7385.000000
# mean         3.160068     5.615030                         12.556534
# std          1.354170     1.828307                          3.500274
# min          0.900000     3.000000                          4.200000
# 25%          2.000000     4.000000                         10.100000
# 50%          3.000000     6.000000                         12.100000
# 75%          3.700000     6.000000                         14.600000
# max          8.400000    16.000000                         30.600000
#
#        Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# count                      7385.000000                       7385.000000
# mean                          9.041706                         10.975071
# std                           2.224456                          2.892506
# ...

# %%
df.dtypes
df = df.select_dtypes(include = ['int64','float64'])
df = df.fillna(df.mean())
df
# Out:
#       Engine Size(L)  Cylinders  Fuel Consumption City (L/100 km)  \
# 0                2.0          4                               9.9
# 1                2.4          4                              11.2
# 2                1.5          4                               6.0
# 3                3.5          6                              12.7
# 4                3.5          6                              12.1
# ...              ...        ...                               ...
# 7380             2.0          4                              10.7
# 7381             2.0          4                              11.2
# 7382             2.0          4                              11.7
# 7383             2.0          4                              11.2
# 7384             2.0          4                              12.2
#
#       Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                                 6.7                               8.5
# ...

# %%
df.columns
# Out:
# Index(['Engine Size(L)', 'Cylinders', 'Fuel Consumption City (L/100 km)',
#        'Fuel Consumption Hwy (L/100 km)', 'Fuel Consumption Comb (L/100 km)',
#        'Fuel Consumption Comb (mpg)', 'CO2 Emissions(g/km)'],
#       dtype='object')

# %%
df.columns = ['Engine Size(L)', 'Cylinders','Fuel Consumption City (L/100 km)','Fuel Consumption Hwy (L/100 km)','Fuel Consumption Comb (L/100 km)','Fuel Consumption Comb (mpg)', 'CO2 Emissions(g/km)',]
df.head()
# Out:
#    Engine Size(L)  Cylinders  Fuel Consumption City (L/100 km)  \
# 0             2.0          4                               9.9
# 1             2.4          4                              11.2
# 2             1.5          4                               6.0
# 3             3.5          6                              12.7
# 4             3.5          6                              12.1
#
#    Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                              6.7                               8.5
# 1                              7.7                               9.6
# 2                              5.8                               5.9
# 3                              9.1                              11.1
# 4                              8.7                              10.6
#
#    Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 0                           33                  196
# 1                           29                  221
# ...

# %% [markdown]
# Selection & Analysis

# %%
sns.pairplot(df)

# %%
df_sel = df[['Engine Size(L)', 'Cylinders','Fuel Consumption City (L/100 km)','Fuel Consumption Hwy (L/100 km)','Fuel Consumption Comb (L/100 km)','Fuel Consumption Comb (mpg)', 'CO2 Emissions(g/km)']]
df_sel.describe()
# Out:
#        Engine Size(L)    Cylinders  Fuel Consumption City (L/100 km)  \
# count     7385.000000  7385.000000                       7385.000000
# mean         3.160068     5.615030                         12.556534
# std          1.354170     1.828307                          3.500274
# min          0.900000     3.000000                          4.200000
# 25%          2.000000     4.000000                         10.100000
# 50%          3.000000     6.000000                         12.100000
# 75%          3.700000     6.000000                         14.600000
# max          8.400000    16.000000                         30.600000
#
#        Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# count                      7385.000000                       7385.000000
# mean                          9.041706                         10.975071
# std                           2.224456                          2.892506
# ...

# %%
sns.pairplot(df_sel)

# %% [markdown]
# Silinder yang mengeluarkan lebih banyak CO2 Emisi

# %%
sns.scatterplot(y = 'CO2 Emissions(g/km)', x = 'Engine Size(L)', data = df_sel, hue = 'Cylinders')
